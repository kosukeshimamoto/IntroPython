# %% [markdown]
# # 索引
# - `!=` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `#` [1/1-1#コメント](1/1-1.ipynb#コメント)
# - `%` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - `*` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算), [2/2-1#文字列の連結](2/2-1.ipynb#文字列の連結), [2/2-2#リストと演算子](2/2-2.ipynb#リストと演算子), [4/4-3#from](4/4-3.ipynb#from), [4/4-4#自作モジュールの使い方](4/4-4.ipynb#自作モジュールの使い方)
# - `**` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - `+` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算), [1/1-1#単項の `+` と `-`](1/1-1.ipynb#単項の-+-と--), [2/2-2#リストと演算子](2/2-2.ipynb#リストと演算子)
# - `+=` [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - `-` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算), [1/1-1#単項の `+` と `-`](1/1-1.ipynb#単項の-+-と--)
# - `-=` [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - `/` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - `//` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 3 項演算子 [2/2-3#▲3 項演算子（条件式）](2/2-3.ipynb#▲3-項演算子（条件式）)
# - `<` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `<=` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `==` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `>` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `>=` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - CSVファイル [7/7-1#CSVファイルからのデータフレームの作成](7/7-1.ipynb#CSVファイルからのデータフレームの作成), [appendix/4-csv#CSVファイルの読み込み](appendix/4-csv.ipynb#CSVファイルの読み込み)
# - CSVライター [appendix/4-csv#CSVファイルの書き込み](appendix/4-csv.ipynb#CSVファイルの書き込み)
# - CSVリーダー [appendix/4-csv#CSVファイルの読み込み](appendix/4-csv.ipynb#CSVファイルの読み込み)
# - DataFrame [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - `False` [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - JSON形式 [appendix/4-json#JSON形式とは](appendix/4-json.ipynb#JSON形式とは)
# - `KMeans` [7/7-2#教師なし学習・クラスタリングの例](7/7-2.ipynb#教師なし学習・クラスタリングの例)
# - `LinearRegression` [7/7-2#教師あり学習・回帰の例](7/7-2.ipynb#教師あり学習・回帰の例)
# - `LogisticRegression` [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - Matplotlib [appendix/5-matplotlib#▲Matplotlibライブラリ](appendix/5-matplotlib.ipynb#▲Matplotlibライブラリ)
# - `None` [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [1/1-3#▲None](1/1-3.ipynb#▲None)
# - OOP [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - `PCA` [7/7-2#教師なし学習・次元削減の例](7/7-2.ipynb#教師なし学習・次元削減の例)
# - Pythonスクリプト [5/5-1#5-1. Pythonスクリプトとコマンドライン実行](5/5-1.ipynb#5-1.-Pythonスクリプトとコマンドライン実行)
# - Series [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - `StopIteration` [6/6-1#イテレータ](6/6-1.ipynb#イテレータ)
# - `True` [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - `\` [2/2-3#▲複数行にまたがる条件式](2/2-3.ipynb#▲複数行にまたがる条件式)
# - `__class__` [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド)
# - `__getitem__()` [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - `__missing__()` [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - `__name__` [5/5-1#モジュールのコマンドライン実行](5/5-1.ipynb#モジュールのコマンドライン実行)
# - `__setitem__()` [6/6-2#練習](6/6-2.ipynb#練習)
# - `__str__()` [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - add [appendix/2-set#add](appendix/2-set.ipynb#add)
# - `and` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `append` [2/2-2#リストに要素を追加する](2/2-2.ipynb#リストに要素を追加する), [7/7-1#行の追加と削除](7/7-1.ipynb#行の追加と削除)
# - argument [3/3-4#引数](3/3-4.ipynb#引数)
# - `as` [4/4-1#ファイルに対する with 文](4/4-1.ipynb#ファイルに対する-with-文), [4/4-3#as](4/4-3.ipynb#as), [4/4-4#自作モジュールの使い方](4/4-4.ipynb#自作モジュールの使い方)
# - `assign` [7/7-1#列の追加と削除](7/7-1.ipynb#列の追加と削除)
# - assignment statement [1/1-2#代入文](1/1-2.ipynb#代入文)
# - augmented assignment statement [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - `bar` [appendix/5-matplotlib#棒グラフ](appendix/5-matplotlib.ipynb#棒グラフ)
# - `bokeh` [appendix/5-bokeh#▲Bokehライブラリ](appendix/5-bokeh.ipynb#▲Bokehライブラリ)
# - `bokeh.models.ColumnDataSource` [appendix/5-bokeh#ヒートマップ](appendix/5-bokeh.ipynb#ヒートマップ)
# - `bokeh.models.LinearColorMapper` [appendix/5-bokeh#ヒートマップ](appendix/5-bokeh.ipynb#ヒートマップ)
# - `bokeh.plotting` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - `bokeh.plotting.figure()` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - `bokeh.plotting.output_file()` [appendix/5-bokeh#グラフのファイル出力](appendix/5-bokeh.ipynb#グラフのファイル出力)
# - `bokeh.plotting.output_notebook()` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - `bokeh.plotting.reset_output()` [appendix/5-bokeh#グラフのファイル出力](appendix/5-bokeh.ipynb#グラフのファイル出力)
# - `bokeh.plotting.show()` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - `break` [3/3-2#`break` 文](3/3-2.ipynb#-break-文)
# - `capitalize` [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - `circle()` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - clear [appendix/2-set#clear](appendix/2-set.ipynb#clear)
# - `close()` [4/4-1#ファイルのクローズ](4/4-1.ipynb#ファイルのクローズ)
# - `collections` [6/6-2#名前付きタプルの用途](6/6-2.ipynb#名前付きタプルの用途)
# - `collections.Counter` [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - `collections.namedtuple()` [6/6-2#▲名前付きタプル](6/6-2.ipynb#▲名前付きタプル)
# - `concat` [7/7-1#▲データの連結](7/7-1.ipynb#▲データの連結)
# - continue [3/3-2#continue文](3/3-2.ipynb#continue文)
# - `copy` [3/3-1#▲辞書を複製する](3/3-1.ipynb#▲辞書を複製する)
# - `count` [2/2-1#数え上げ](2/2-1.ipynb#数え上げ), [2/2-2#指定した要素のインデックス取得、数えあげ](2/2-2.ipynb#指定した要素のインデックス取得、数えあげ)
# - `cross()` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - `csv` [appendix/4-csv#CSVファイルの読み込み](appendix/4-csv.ipynb#CSVファイルの読み込み), [appendix/4-csv#CSVファイルの書き込み](appendix/4-csv.ipynb#CSVファイルの書き込み)
# - `csv.reader` [appendix/4-csv#CSVファイルの読み込み](appendix/4-csv.ipynb#CSVファイルの読み込み)
# - `csv.writer` [appendix/4-csv#CSVファイルの書き込み](appendix/4-csv.ipynb#CSVファイルの書き込み)
# - `def` [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値)
# - `del` [2/2-2#▲リスト要素を削除する](2/2-2.ipynb#▲リスト要素を削除する), [3/3-1#3-1. 辞書型 (dictionary)](3/3-1.ipynb#3-1.-辞書型-(dictionary)), [7/7-1#列の追加と削除](7/7-1.ipynb#列の追加と削除)
# - `describe()` [7/7-1#データの統計量](7/7-1.ipynb#データの統計量)
# - difference [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - discard [appendix/2-set#discard](appendix/2-set.ipynb#discard)
# - `drop` [7/7-1#列の追加と削除](7/7-1.ipynb#列の追加と削除), [7/7-1#行の追加と削除](7/7-1.ipynb#行の追加と削除)
# - `elif` [2/2-3#`if` ... `elif` ... `else` による条件分岐](2/2-3.ipynb#-if-...-elif-...-else-による条件分岐)
# - `else` [1/1-3#`if` による条件分岐](1/1-3.ipynb#-if-による条件分岐), [2/2-3#`if` ... `else` による条件分岐](2/2-3.ipynb#-if-...-else-による条件分岐), [2/2-3#`if` ... `elif` ... `else` による条件分岐](2/2-3.ipynb#-if-...-elif-...-else-による条件分岐), [3/3-2#▲for, while 繰り返し文における `else`](3/3-2.ipynb#▲for,-while-繰り返し文における-else)
# - `encoding` [appendix/4-csv#東京の7月の気温](appendix/4-csv.ipynb#東京の7月の気温)
# - enumerate [3/3-2#enumerate関数](3/3-2.ipynb#enumerate関数)
# - `enumerate()` [6/6-1#enumerate](6/6-1.ipynb#enumerate)
# - `extend` [2/2-2#▲リストにリストを追加する](2/2-2.ipynb#▲リストにリストを追加する)
# - `filter()` [6/6-1#filter](6/6-1.ipynb#filter)
# - `find` [2/2-1#検索](2/2-1.ipynb#検索)
# - `fit` [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - `flatten()` [5/5-2#多次元配列](5/5-2.ipynb#多次元配列)
# - `for` [3/3-2#`for` による繰り返し](3/3-2.ipynb#-for-による繰り返し)
# - `from` [4/4-3#from](4/4-3.ipynb#from), [4/4-4#自作モジュールの使い方](4/4-4.ipynb#自作モジュールの使い方)
# - functional programming [6/6-1#6-1. 関数プログラミング](6/6-1.ipynb#6-1.-関数プログラミング)
# - `functool.reduce()` [6/6-1#▲reduce](6/6-1.ipynb#▲reduce)
# - `get` [3/3-1#キーを指定して値を得るメソッド](3/3-1.ipynb#キーを指定して値を得るメソッド)
# - `grid` [appendix/5-matplotlib#線グラフ](appendix/5-matplotlib.ipynb#線グラフ)
# - `groupby` [7/7-1#▲データのグループ化](7/7-1.ipynb#▲データのグループ化)
# - higher-order function [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - `hist` [appendix/5-matplotlib#ヒストグラム](appendix/5-matplotlib.ipynb#ヒストグラム)
# - `if` [1/1-3#`if` による条件分岐](1/1-3.ipynb#-if-による条件分岐), [2/2-3#2-3. 条件分岐](2/2-3.ipynb#2-3.-条件分岐), [2/2-3#`if` ... `else` による条件分岐](2/2-3.ipynb#-if-...-else-による条件分岐), [2/2-3#`if` ... `elif` ... `else` による条件分岐](2/2-3.ipynb#-if-...-elif-...-else-による条件分岐)
# - `iloc` [7/7-1#ilocとloc](7/7-1.ipynb#ilocとloc)
# - `import` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [4/4-3#モジュールの `import`](4/4-3.ipynb#モジュールの-import)
# - `import`文 [4/4-4#自作モジュールの使い方](4/4-4.ipynb#自作モジュールの使い方)
# - `in` [2/2-1#文字列の検索](2/2-1.ipynb#文字列の検索), [2/2-2#リストと演算子](2/2-2.ipynb#リストと演算子), [3/3-1#3-1. 辞書型 (dictionary)](3/3-1.ipynb#3-1.-辞書型-(dictionary)), [3/3-2#帰属演算子 `in`](3/3-2.ipynb#帰属演算子-in)
# - in-place [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - `index` [2/2-1#検索](2/2-1.ipynb#検索), [2/2-2#指定した要素のインデックス取得、数えあげ](2/2-2.ipynb#指定した要素のインデックス取得、数えあげ)
# - inheritance [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - insert [2/2-2#▲リストに要素を挿入する](2/2-2.ipynb#▲リストに要素を挿入する)
# - intersection [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - `isinstance()` [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - `items` [3/3-1#キー、値の一覧を得る](3/3-1.ipynb#キー、値の一覧を得る)
# - `iter()` [6/6-1#イテレータ](6/6-1.ipynb#イテレータ)
# - `itertools` [6/6-1#▲chain](6/6-1.ipynb#▲chain)
# - `itertools.chain()` [6/6-1#▲chain](6/6-1.ipynb#▲chain)
# - `itertools.chain.from_iterable()` [6/6-1#▲chain](6/6-1.ipynb#▲chain)
# - `json` [appendix/4-json#JSONファイルのダンプとロード](appendix/4-json.ipynb#JSONファイルのダンプとロード)
# - `json.dump` [appendix/4-json#JSONファイルのダンプとロード](appendix/4-json.ipynb#JSONファイルのダンプとロード)
# - `json.dumps` [appendix/4-json#JSONファイルのダンプとロード](appendix/4-json.ipynb#JSONファイルのダンプとロード), [appendix/4-json#JSONファイルのダンプとロード](appendix/4-json.ipynb#JSONファイルのダンプとロード)
# - `json.load` [appendix/4-json#JSONファイルのダンプとロード](appendix/4-json.ipynb#JSONファイルのダンプとロード)
# - `keys` [3/3-1#キーの一覧を得る](3/3-1.ipynb#キーの一覧を得る)
# - `legend` [appendix/5-matplotlib#線グラフ](appendix/5-matplotlib.ipynb#線グラフ)
# - `len` [2/2-1#2-1. 文字列型 (string)](2/2-1.ipynb#2-1.-文字列型-(string)), [2/2-2#リストの要素数](2/2-2.ipynb#リストの要素数), [3/3-1#3-1. 辞書型 (dictionary)](3/3-1.ipynb#3-1.-辞書型-(dictionary))
# - `line()` [appendix/5-bokeh#線グラフ](appendix/5-bokeh.ipynb#線グラフ)
# - `list` [2/2-2#タプル型(tuple)](2/2-2.ipynb#タプル型(tuple))
# - `loc` [7/7-1#ilocとloc](7/7-1.ipynb#ilocとloc)
# - `lower` [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - maintainability [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - `map()` [6/6-1#map](6/6-1.ipynb#map)
# - `match` [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - matchオブジェクト [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - `math` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.cos` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.pi` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.sin` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.sqrt` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - matplotlib [appendix/2-visuallization#matplotlib](appendix/2-visuallization.ipynb#matplotlib)
# - `max()` [5/5-2#sum, max, min, mean](5/5-2.ipynb#sum,-max,-min,-mean), [6/6-1#max, min](6/6-1.ipynb#max,-min)
# - `mean()` [5/5-2#sum, max, min, mean](5/5-2.ipynb#sum,-max,-min,-mean)
# - `merge` [7/7-1#▲データの結合](7/7-1.ipynb#▲データの結合)
# - `min()` [5/5-2#sum, max, min, mean](5/5-2.ipynb#sum,-max,-min,-mean), [6/6-1#max, min](6/6-1.ipynb#max,-min)
# - modularity [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - `next` [4/4-1#ファイルに対する for 文](4/4-1.ipynb#ファイルに対する-for-文), [appendix/4-csv#CSVファイルの読み込み](appendix/4-csv.ipynb#CSVファイルの読み込み)
# - `next()` [6/6-1#イテレータ](6/6-1.ipynb#イテレータ)
# - `not` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `numpy` [5/5-2#5-2. NumPy](5/5-2.ipynb#5-2.-NumPy)
# - `numpy.arange()` [5/5-2#arange](5/5-2.ipynb#arange)
# - `numpy.array()` [5/5-2#配列の構築](5/5-2.ipynb#配列の構築)
# - `numpy.bool` [5/5-2#要素型](5/5-2.ipynb#要素型)
# - `numpy.complex128` [5/5-2#要素型](5/5-2.ipynb#要素型)
# - `numpy.dot()` [5/5-2#dot](5/5-2.ipynb#dot)
# - `numpy.float64` [5/5-2#要素型](5/5-2.ipynb#要素型)
# - `numpy.histogram()` [appendix/5-bokeh#ヒストグラム](appendix/5-bokeh.ipynb#ヒストグラム)
# - `numpy.identity()` [5/5-2#▲線形代数の演算](5/5-2.ipynb#▲線形代数の演算)
# - `numpy.int32` [5/5-2#要素型](5/5-2.ipynb#要素型)
# - `numpy.linalg` [5/5-2#▲線形代数の演算](5/5-2.ipynb#▲線形代数の演算)
# - `numpy.linalg.norm()` [5/5-2#▲線形代数の演算](5/5-2.ipynb#▲線形代数の演算)
# - `numpy.linspace()` [5/5-2#linspace](5/5-2.ipynb#linspace)
# - `numpy.loadtxt()` [5/5-2#配列の保存と復元](5/5-2.ipynb#配列の保存と復元)
# - `numpy.matmul()` [5/5-2#▲線形代数の演算](5/5-2.ipynb#▲線形代数の演算)
# - `numpy.ndarray` [5/5-2#配列の構築](5/5-2.ipynb#配列の構築)
# - `numpy.ones()` [5/5-2#zeros, ones](5/5-2.ipynb#zeros,-ones)
# - `numpy.random.binomial()` [5/5-2#random.rand](5/5-2.ipynb#random.rand)
# - `numpy.random.poisson()` [5/5-2#random.rand](5/5-2.ipynb#random.rand)
# - `numpy.random.rand()` [5/5-2#random.rand](5/5-2.ipynb#random.rand)
# - `numpy.random.randn()` [5/5-2#random.rand](5/5-2.ipynb#random.rand)
# - `numpy.savetxt()` [5/5-2#配列の保存と復元](5/5-2.ipynb#配列の保存と復元)
# - `numpy.sort()` [5/5-2#sort](5/5-2.ipynb#sort)
# - `numpy.sqrt()` [5/5-2#ユニバーサル関数](5/5-2.ipynb#ユニバーサル関数)
# - `numpy.zeros()` [5/5-2#zeros, ones](5/5-2.ipynb#zeros,-ones)
# - object-oriented programming [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - `open()` [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - `or` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - override [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - pandas [7/7-1#7-1. pandasライブラリ](7/7-1.ipynb#7-1.-pandasライブラリ)
# - parameter [3/3-4#引数](3/3-4.ipynb#引数)
# - `pass` [3/3-2#`pass` 文](3/3-2.ipynb#-pass-文)
# - `plot` [appendix/5-matplotlib#線グラフ](appendix/5-matplotlib.ipynb#線グラフ)
# - pop [appendix/2-set#pop](appendix/2-set.ipynb#pop)
# - `predict` [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - `print` [1/1-2#print](1/1-2.ipynb#print)
# - `quad()` [appendix/5-bokeh#ヒストグラム](appendix/5-bokeh.ipynb#ヒストグラム)
# - range [3/3-2#range関数](3/3-2.ipynb#range関数)
# - `ravel()` [5/5-2#多次元配列](5/5-2.ipynb#多次元配列)
# - `re.I` [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - `re.IGNORECASE` [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - `read()` [4/4-1#ファイル全体の読み込み](4/4-1.ipynb#ファイル全体の読み込み)
# - `read_csv` [7/7-1#CSVファイルからのデータフレームの作成](7/7-1.ipynb#CSVファイルからのデータフレームの作成)
# - `readline()` [4/4-1#行の読み込み](4/4-1.ipynb#行の読み込み)
# - remove [appendix/2-set#remove](appendix/2-set.ipynb#remove)
# - `replace` [2/2-1#置換](2/2-1.ipynb#置換)
# - `reshape()` [5/5-2#多次元配列](5/5-2.ipynb#多次元配列)
# - `return` [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-2#制御構造と `return`](3/3-2.ipynb#制御構造と-return)
# - `reverse` [2/2-2#▲リストの要素を逆順にする](2/2-2.ipynb#▲リストの要素を逆順にする)
# - `reversed()` [6/6-1#▲reversed](6/6-1.ipynb#▲reversed)
# - `rstrip('\n')` [4/4-1#改行文字の削除](4/4-1.ipynb#改行文字の削除)
# - `savefig` [appendix/5-matplotlib#グラフの画像ファイル出力](appendix/5-matplotlib.ipynb#グラフの画像ファイル出力)
# - `scatter` [appendix/5-matplotlib#散布図](appendix/5-matplotlib.ipynb#散布図)
# - `scatter()` [appendix/5-bokeh#散布図](appendix/5-bokeh.ipynb#散布図)
# - scikit-learn [7/7-2#7-2. scikit-learnライブラリ](7/7-2.ipynb#7-2.-scikit-learnライブラリ)
# - `search` [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - `set` [appendix/2-set#▲セット型 (set)](appendix/2-set.ipynb#▲セット型-(set))
# - `setdefault` [3/3-1#▲キーがない場合に登録をおこなう](3/3-1.ipynb#▲キーがない場合に登録をおこなう)
# - shebang [5/5-1#shebang](5/5-1.ipynb#shebang)
# - `sort` [2/2-2#並べ替え(`sort` メソッド)](2/2-2.ipynb#並べ替え(-sort-メソッド))
# - `sort()` [5/5-2#sort](5/5-2.ipynb#sort)
# - `sort_index()` [7/7-1#データの並び替え](7/7-1.ipynb#データの並び替え)
# - `sort_values()` [7/7-1#データの並び替え](7/7-1.ipynb#データの並び替え)
# - `sorted` [2/2-2#並べ替え(`sorted` 組み込み関数)](2/2-2.ipynb#並べ替え(-sorted-組み込み関数))
# - `sorted()` [6/6-1#sorted](6/6-1.ipynb#sorted)
# - split [appendix/5-re#re.split](appendix/5-re.ipynb#re.split)
# - `str` [2/2-1#2-1. 文字列型 (string)](2/2-1.ipynb#2-1.-文字列型-(string))
# - `strip()` [appendix/4-json#不要な空白や改行の除去](appendix/4-json.ipynb#不要な空白や改行の除去)
# - sub [appendix/5-re#sub](appendix/5-re.ipynb#sub)
# - `sum()` [5/5-2#sum, max, min, mean](5/5-2.ipynb#sum,-max,-min,-mean)
# - `super()` [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - `title` [appendix/5-matplotlib#線グラフ](appendix/5-matplotlib.ipynb#線グラフ)
# - `transform` [7/7-2#教師なし学習・次元削減の例](7/7-2.ipynb#教師なし学習・次元削減の例)
# - `tuple` [2/2-2#タプル型(tuple)](2/2-2.ipynb#タプル型(tuple))
# - `type` [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [2/2-1#2-1. 文字列型 (string)](2/2-1.ipynb#2-1.-文字列型-(string))
# - `type()` [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - union [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - `upper` [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - `values` [3/3-1#値の一覧を得る](3/3-1.ipynb#値の一覧を得る)
# - `vbar()` [appendix/5-bokeh#棒グラフ](appendix/5-bokeh.ipynb#棒グラフ)
# - `while` [3/3-2#`while` による繰り返し](3/3-2.ipynb#-while-による繰り返し)
# - `with` [4/4-1#ファイルに対する with 文](4/4-1.ipynb#ファイルに対する-with-文)
# - `write()` [4/4-1#ファイルへの書き込み](4/4-1.ipynb#ファイルへの書き込み)
# - `xlabel` [appendix/5-matplotlib#線グラフ](appendix/5-matplotlib.ipynb#線グラフ)
# - `ylabel` [appendix/5-matplotlib#線グラフ](appendix/5-matplotlib.ipynb#線グラフ)
# - `zip()` [6/6-1#▲zip](6/6-1.ipynb#▲zip)
# - 値(value) [3/3-1#3-1. 辞書型 (dictionary)](3/3-1.ipynb#3-1.-辞書型-(dictionary))
# - 余り [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - イテラブル [6/6-1#イテレータ](6/6-1.ipynb#イテレータ), [appendix/6-iterable#イテレータとイテラブルの定義](appendix/6-iterable.ipynb#イテレータとイテラブルの定義)
# - イテラブル（iterable） [appendix/6-iterable#イテラブルとfor文](appendix/6-iterable.ipynb#イテラブルとfor文)
# - イテレータ [3/3-3#▲ジェネレータ式](3/3-3.ipynb#▲ジェネレータ式), [4/4-1#ファイルに対する for 文](4/4-1.ipynb#ファイルに対する-for-文), [6/6-1#イテレータ](6/6-1.ipynb#イテレータ), [appendix/4-csv#CSVファイルの読み込み](appendix/4-csv.ipynb#CSVファイルの読み込み), [appendix/6-iterable#イテレータとイテラブルの定義](appendix/6-iterable.ipynb#イテレータとイテラブルの定義)
# - 入れ子 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [2/2-3#`if` ... `else` による条件分岐](2/2-3.ipynb#-if-...-else-による条件分岐), [3/3-2#for文の入れ子](3/3-2.ipynb#for文の入れ子)
# - インスタンス [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - インデックス [2/2-1#文字列とインデックス](2/2-1.ipynb#文字列とインデックス), [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - インデント [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [2/2-3#インデントによる構文](2/2-3.ipynb#インデントによる構文)
# - インプレース [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - インポート [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [4/4-3#モジュールの `import`](4/4-3.ipynb#モジュールの-import)
# - エスケープシーケンス [2/2-1#▲エスケープシーケンス](2/2-1.ipynb#▲エスケープシーケンス), [4/4-1#ファイルへの書き込み](4/4-1.ipynb#ファイルへの書き込み)
# - エラー [1/1-1#エラー](1/1-1.ipynb#エラー)
# - 大文字 [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - オブジェクト [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - オブジェクト指向プログラミング [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - 親クラス [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - オーバーライド [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - オープン [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - 返値 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#返値](3/3-4.ipynb#返値)
# - 書き込みモード [4/4-1#ファイルへの書き込み](4/4-1.ipynb#ファイルへの書き込み)
# - 掛け算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 数え上げ [2/2-1#数え上げ](2/2-1.ipynb#数え上げ)
# - 型 [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド)
# - 形 [5/5-2#多次元配列](5/5-2.ipynb#多次元配列)
# - 括弧 [1/1-1#演算子の優先順位と括弧](1/1-1.ipynb#演算子の優先順位と括弧)
# - 仮引数 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#引数](3/3-4.ipynb#引数)
# - カレントディレクトリ [4/4-2#カレントディレクトリ](4/4-2.ipynb#カレントディレクトリ)
# - 関数 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#関数の定義](3/3-4.ipynb#関数の定義)
# - 関数定義 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値)
# - 関数内関数 [6/6-1#▲関数内関数（クロージャ）](6/6-1.ipynb#▲関数内関数（クロージャ）)
# - 関数プログラミング [6/6-1#6-1. 関数プログラミング](6/6-1.ipynb#6-1.-関数プログラミング)
# - 機械学習 [7/7-2#機械学習について](7/7-2.ipynb#機械学習について)
# - 教師あり学習 [7/7-2#教師あり学習](7/7-2.ipynb#教師あり学習)
# - 教師なし学習 [7/7-2#教師なし学習](7/7-2.ipynb#教師なし学習)
# - キー(key) [3/3-1#3-1. 辞書型 (dictionary)](3/3-1.ipynb#3-1.-辞書型-(dictionary))
# - 偽 [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - 空行 [1/1-2#コメントと空行](1/1-2.ipynb#コメントと空行)
# - 空タプル [2/2-2#タプル型(tuple)](2/2-2.ipynb#タプル型(tuple))
# - 空白 [1/1-1#空白](1/1-1.ipynb#空白)
# - 空文字列 [2/2-1#空文字列](2/2-1.ipynb#空文字列), [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - 空リスト [2/2-2#2-2. リスト型 (list)](2/2-2.ipynb#2-2.-リスト型-(list))
# - 空列 [2/2-1#空文字列](2/2-1.ipynb#空文字列), [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - 組み込み関数 [1/1-2#print](1/1-2.ipynb#print)
# - クラス [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - クラス属性 [6/6-2#▲クラス属性](6/6-2.ipynb#▲クラス属性)
# - クラスタリング [7/7-2#教師なし学習・クラスタリングの例](7/7-2.ipynb#教師なし学習・クラスタリングの例)
# - 繰り返し [3/3-2#3-2. 繰り返し](3/3-2.ipynb#3-2.-繰り返し)
# - クローズ [4/4-1#ファイルのクローズ](4/4-1.ipynb#ファイルのクローズ)
# - グローバル変数 [1/1-2#▲グローバル変数](1/1-2.ipynb#▲グローバル変数), [3/3-4#変数とスコープ](3/3-4.ipynb#変数とスコープ)
# - 継承 [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - 検索 [2/2-1#検索](2/2-1.ipynb#検索)
# - 高階関数 [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - 子クラス [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - コマンドライン実行 [5/5-1#5-1. Pythonスクリプトとコマンドライン実行](5/5-1.ipynb#5-1.-Pythonスクリプトとコマンドライン実行)
# - コマンドライン引数 [5/5-1#コマンドライン引数](5/5-1.ipynb#コマンドライン引数)
# - コメント [1/1-1#コメント](1/1-1.ipynb#コメント), [1/1-2#コメントと空行](1/1-2.ipynb#コメントと空行)
# - 小文字 [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - コンストラクタ [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - 再帰 [1/1-3#▲再帰](1/1-3.ipynb#▲再帰)
# - 再帰関数 [appendix/3-recursion#▲再帰](appendix/3-recursion.ipynb#▲再帰)
# - 再帰呼出し [appendix/3-recursion#▲再帰](appendix/3-recursion.ipynb#▲再帰)
# - 差集合 [appendix/2-set#集合演算](appendix/2-set.ipynb#集合演算), [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - 参照値 [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド)
# - 集合演算 [appendix/2-set#集合演算](appendix/2-set.ipynb#集合演算)
# - 集合内包表記 [3/3-3#▲集合内包表記](3/3-3.ipynb#▲集合内包表記)
# - シリーズ [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - 真 [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - 真理値 [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - 真理値配列によるインデックスアクセス [5/5-2#▲真理値配列によるインデックスアクセス](5/5-2.ipynb#▲真理値配列によるインデックスアクセス)
# - ジェネレータ [appendix/6-iterable#ジェネレータ関数と無限イテレータ](appendix/6-iterable.ipynb#ジェネレータ関数と無限イテレータ)
# - ジェネレータイテレータ [appendix/6-iterable#ジェネレータ関数と無限イテレータ](appendix/6-iterable.ipynb#ジェネレータ関数と無限イテレータ)
# - ジェネレータ関数 [appendix/6-iterable#ジェネレータ関数と無限イテレータ](appendix/6-iterable.ipynb#ジェネレータ関数と無限イテレータ)
# - ジェネレータ式 [3/3-3#▲ジェネレータ式](3/3-3.ipynb#▲ジェネレータ式)
# - 次元削減 [7/7-2#教師なし学習・次元削減の例](7/7-2.ipynb#教師なし学習・次元削減の例)
# - 辞書型 [3/3-1#3-1. 辞書型 (dictionary)](3/3-1.ipynb#3-1.-辞書型-(dictionary))
# - 辞書内包表記 [3/3-3#▲辞書内包表記](3/3-3.ipynb#▲辞書内包表記)
# - 実行エラー [1/1-1#エラー](1/1-1.ipynb#エラー), [1/1-4#1-4. デバッグ](1/1-4.ipynb#1-4.-デバッグ), [1/1-4#実行エラー：Runtime Errors](1/1-4.ipynb#実行エラー：Runtime-Errors)
# - 実数 [1/1-1#整数と実数](1/1-1.ipynb#整数と実数)
# - 実引数 [3/3-4#引数](3/3-4.ipynb#引数)
# - 条件付き内包表記 [3/3-3#▲条件付き内包表記](3/3-3.ipynb#▲条件付き内包表記)
# - 条件分岐 [1/1-3#`if` による条件分岐](1/1-3.ipynb#-if-による条件分岐), [2/2-3#2-3. 条件分岐](2/2-3.ipynb#2-3.-条件分岐)
# - スライス [2/2-1#文字列とスライス](2/2-1.ipynb#文字列とスライス), [7/7-1#データの参照](7/7-1.ipynb#データの参照)
# - 正規表現 [appendix/5-re#▲正規表現](appendix/5-re.ipynb#▲正規表現)
# - 整除 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 整数 [1/1-1#整数と実数](1/1-1.ipynb#整数と実数)
# - 積集合 [appendix/2-set#集合演算](appendix/2-set.ipynb#集合演算), [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - セット型 [appendix/2-set#▲セット型 (set)](appendix/2-set.ipynb#▲セット型-(set))
# - 線形回帰 [7/7-2#教師あり学習・回帰の例](7/7-2.ipynb#教師あり学習・回帰の例), [appendix/4-csv#東京の7月の気温](appendix/4-csv.ipynb#東京の7月の気温)
# - 選択 [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - 絶対パス [4/4-2#相対パスと絶対パス](4/4-2.ipynb#相対パスと絶対パス)
# - 相対パス [4/4-2#相対パスと絶対パス](4/4-2.ipynb#相対パスと絶対パス)
# - 対称差 [appendix/2-set#集合演算](appendix/2-set.ipynb#集合演算), [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - 足し算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 多次元配列 [5/5-2#多次元配列](5/5-2.ipynb#多次元配列)
# - 多重代入 [2/2-2#多重代入](2/2-2.ipynb#多重代入)
# - 多重リスト [2/2-2#多重リスト](2/2-2.ipynb#多重リスト)
# - タプル型 [2/2-2#タプル型(tuple)](2/2-2.ipynb#タプル型(tuple))
# - 単項 [1/1-1#単項の `+` と `-`](1/1-1.ipynb#単項の-+-と--)
# - 代入演算子 [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - 代入文 [1/1-2#代入文](1/1-2.ipynb#代入文)
# - 置換 [2/2-1#置換](2/2-1.ipynb#置換)
# - デバッグ [1/1-2#print](1/1-2.ipynb#print), [1/1-4#1-4. デバッグ](1/1-4.ipynb#1-4.-デバッグ)
# - データフレーム [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - 特徴量 [7/7-2#データ](7/7-2.ipynb#データ)
# - 内包表記 [3/3-3#3-3. 内包表記](3/3-3.ipynb#3-3.-内包表記)
# - 名前付きタプル [6/6-2#▲名前付きタプル](6/6-2.ipynb#▲名前付きタプル)
# - ネスト [2/2-3#`if` ... `else` による条件分岐](2/2-3.ipynb#-if-...-else-による条件分岐)
# - 配列 [2/2-2#2-2. リスト型 (list)](2/2-2.ipynb#2-2.-リスト型-(list)), [5/5-2#配列の構築](5/5-2.ipynb#配列の構築)
# - 配列同士の演算 [5/5-2#配列同士の演算](5/5-2.ipynb#配列同士の演算)
# - 配列のスカラ―演算 [5/5-2#配列のスカラ―演算](5/5-2.ipynb#配列のスカラ―演算)
# - 配列のデータ属性 [5/5-2#▲配列のデータ属性](5/5-2.ipynb#▲配列のデータ属性)
# - 破壊的 [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - 半角の空白 [1/1-1#空白](1/1-1.ipynb#空白)
# - バグ [1/1-2#print](1/1-2.ipynb#print), [1/1-4#1-4. デバッグ](1/1-4.ipynb#1-4.-デバッグ)
# - パス [4/4-2#カレントディレクトリ](4/4-2.ipynb#カレントディレクトリ)
# - パターン [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - 比較演算 [appendix/2-set#比較演算](appendix/2-set.ipynb#比較演算)
# - 比較演算子 [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - 引き算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 引数 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#関数の定義](3/3-4.ipynb#関数の定義)
# - 否定文字クラス [appendix/5-re#否定文字クラス](appendix/5-re.ipynb#否定文字クラス)
# - 非破壊的 [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - ファイル [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - 浮動小数点数 [1/1-1#整数と実数](1/1-1.ipynb#整数と実数)
# - 分割 [2/2-1#分割](2/2-1.ipynb#分割)
# - 分割統治 [appendix/3-recursion#▲再帰](appendix/3-recursion.ipynb#▲再帰)
# - 文法エラー [1/1-1#エラー](1/1-1.ipynb#エラー), [1/1-4#1-4. デバッグ](1/1-4.ipynb#1-4.-デバッグ), [1/1-4#文法エラー：Syntax Errors](1/1-4.ipynb#文法エラー：Syntax-Errors)
# - ブールインデックス参照 [7/7-1#データの条件取り出し](7/7-1.ipynb#データの条件取り出し)
# - 閉包 [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - 変数 [1/1-2#変数](1/1-2.ipynb#変数), [2/2-1#初心者によくある誤解、変数と文字列の混乱](2/2-1.ipynb#初心者によくある誤解、変数と文字列の混乱)
# - べき乗 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - べき表示 [1/1-1#実数のべき表示](1/1-1.ipynb#実数のべき表示)
# - 保守性 [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - マッチする [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本), [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - 無名関数 [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - メソッド [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [2/2-1#文字列とメソッド](2/2-1.ipynb#文字列とメソッド), [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - 文字クラス [appendix/5-re#文字クラス](appendix/5-re.ipynb#文字クラス), [appendix/5-re#文字クラス](appendix/5-re.ipynb#文字クラス)
# - 文字コード [4/4-1#ファイルの読み書きにおける文字コード指定](4/4-1.ipynb#ファイルの読み書きにおける文字コード指定), [appendix/4-csv#東京の7月の気温](appendix/4-csv.ipynb#東京の7月の気温)
# - 文字コード宣言 [5/5-1#文字コード宣言](5/5-1.ipynb#文字コード宣言)
# - モジュール [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [4/4-3#モジュールの `import`](4/4-3.ipynb#モジュールの-import), [4/4-4#4-4. モジュールの作り方](4/4-4.ipynb#4-4.-モジュールの作り方)
# - モジュール性 [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - モジュール名 [4/4-4#自作モジュールの使い方](4/4-4.ipynb#自作モジュールの使い方)
# - 文字列 [2/2-1#初心者によくある誤解、変数と文字列の混乱](2/2-1.ipynb#初心者によくある誤解、変数と文字列の混乱)
# - 文字列型 [2/2-1#2-1. 文字列型 (string)](2/2-1.ipynb#2-1.-文字列型-(string))
# - 文字列の比較演算 [2/2-1#文字列の比較演算](2/2-1.ipynb#文字列の比較演算)
# - 優先順位 [1/1-1#演算子の優先順位と括弧](1/1-1.ipynb#演算子の優先順位と括弧)
# - ユニバーサル関数 [5/5-2#ユニバーサル関数](5/5-2.ipynb#ユニバーサル関数)
# - 読み込みモード [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - 予約語 [1/1-2#予約語](1/1-2.ipynb#予約語)
# - ライブラリ [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - ラムダ式 [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - リスト型 [2/2-2#2-2. リスト型 (list)](2/2-2.ipynb#2-2.-リスト型-(list))
# - 累算代入文 [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - ループ [3/3-2#`for` による繰り返し](3/3-2.ipynb#-for-による繰り返し)
# - レシーバ [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - 連接 [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - ロジスティック回帰 [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - 論理エラー [1/1-4#1-4. デバッグ](1/1-4.ipynb#1-4.-デバッグ), [1/1-4#論理エラー：Logical Errors](1/1-4.ipynb#論理エラー：Logical-Errors)
# - ローカル変数 [1/1-2#ローカル変数](1/1-2.ipynb#ローカル変数), [3/3-4#引数](3/3-4.ipynb#引数)
# - 和 [appendix/5-re#正規表現の基本](appendix/5-re.ipynb#正規表現の基本)
# - ワイルドカード [4/4-3#from](4/4-3.ipynb#from)
# - 和集合 [appendix/2-set#集合演算](appendix/2-set.ipynb#集合演算), [appendix/2-set#union, intersection, difference](appendix/2-set.ipynb#union,-intersection,-difference)
# - 割り算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
